# %%
from os import listdir
import pandas

onlyfiles = [f for f in listdir("./../Training_Raw_files_validated/Good_Raw")]
onlyfiles
# Out:
# ['wafer_07012020_041011.csv',
#  'wafer_13012020_090817.csv',
#  'wafer_16012020_051629.csv',
#  'wafer_20012020_090819.csv',
#  'wafer_20022020_090716.csv',
#  'wafer_21012020_080913.csv',
#  'wafer_22022020_041119.csv',
#  'wafer_23012020_011008.csv',
#  'wafer_23012020_041211.csv',
#  'wafer_27012020_080911.csv',
#  'wafer_28012020_051011.csv',
#  'wafer_28012020_090817.csv',
#  'wafer_28042020_031911.csv',
#  'wafer_29012020_050617.csv',
#  'wafer_29012020_060756.csv',
#  'wafer_31012020_090811.csv']

# %%
csv = pandas.read_csv("./../Training_Raw_files_validated/Good_Raw"+"/"+'wafer_07012020_041011.csv')
csv
# Out:
#    Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 0   Wafer-501   3076.81   2158.75  2208.2334  1517.0152    1.0980       100
# 1   Wafer-502   2951.62   2511.92  2253.5111  1397.5060    0.9660       100
# 2   Wafer-503   2930.42   2505.17  2235.0556  1302.6607    1.6347       100
# 3   Wafer-504   2997.28   2357.99  2141.0667  1236.5212    0.9698       100
# 4   Wafer-505   3025.10   2475.18  2235.0556  1302.6607    1.6347       100
# ..        ...       ...       ...        ...        ...       ...       ...
# 95  Wafer-596   2996.89   2492.40  2217.8667  1275.0917    1.5487       100
# 96  Wafer-597   2990.85   2485.99  2167.9444   861.8041    1.4140       100
# 97  Wafer-598   3059.43   2473.55  2214.9333  1663.7024    1.0203       100
# 98  Wafer-599   3024.54   2420.25  2167.9444   861.8041    1.4140       100
# 99  Wafer-600   3069.44   2459.50  2183.5000  1099.0027    1.3593       100
#
# ...

# %%
csv.columns
# Out:
# Index(['Unnamed: 0', 'Sensor-1', 'Sensor-2', 'Sensor-3', 'Sensor-4',
#        'Sensor-5', 'Sensor-6', 'Sensor-7', 'Sensor-8', 'Sensor-9',
#        ...
#        'Sensor-582', 'Sensor-583', 'Sensor-584', 'Sensor-585', 'Sensor-586',
#        'Sensor-587', 'Sensor-588', 'Sensor-589', 'Sensor-590', 'Good/Bad'],
#       dtype='object', length=592)

# %%
for file in onlyfiles:
                    csv = pandas.read_csv("./../Training_Raw_files_validated/Good_Raw"+"/" + file)
                    csv.fillna('NULL',inplace=True)
                    # #csv.update("'"+ csv['Wafer'] +"'")
                    # csv.update(csv['Wafer'].astype(str))
                    csv['Wafer'] = csv['Unnamed: 0'].str[6:]

# %%
csv['Unnamed: 0']
# Out:
# 0     Wafer-301
# 1     Wafer-302
# 2     Wafer-303
# 3     Wafer-304
# 4     Wafer-305
#         ...
# 95    Wafer-396
# 96    Wafer-397
# 97    Wafer-398
# 98    Wafer-399
# 99    Wafer-400
# Name: Unnamed: 0, Length: 100, dtype: object
